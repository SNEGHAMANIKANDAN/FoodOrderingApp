# %%
import re

class Admin:
    
    def __init__(self):
        self.__Uname = 'Admin'
        self.__Password ='password'
        self.FoodId = 1000
        self.foodlist =[]
        self.orders = []
        
    def validate(self,Uname,Password):
        if self.__Uname == Uname and self.__Password == Password:
            return "Access granted"

        else:
            return "Only Admin can alter the information"


    def set_fooditem(self,Foodname):
        print("FoodName",Foodname)
        self.FoodName = Foodname
        print("enter the quantity of food available")
        self.Quantity = int(input())
        print("Enter the price of the food per serve")
        self.Price = float (input())
        print("Enter the maximum discount for the product in percentage")
        self.Discount = float(input())
        self.FoodId += 1
        ds = {"Food ID": self.FoodId,"Food Name": self.FoodName,"Food Quantity": self.Quantity, "Food Price": self.Price,"Discount": self.Discount}
        self.foodlist.append(ds)

    def get_fooditem(self):
        print (self.foodlist, end = '\n')

    def print_items(self):
       # print("\n DISCOUNT APPLICABLE ONLY FOR FIRST TIME USER\n\n\n")
        print('Food ID       Food name      Price')
        for i in self.foodlist:
            print(f"{i['Food ID']} ----- {i['Food Name']} ----- {i['Food Price']} ----- {i['Discount']}")
    
    def printorder(self,food,quantity):
        Ofood = [x+1000 for x in food]
        Oquantity = quantity 
        orderedfoodlist = []
        j=0
        i=0
        while i < (len(self.foodlist)):
            if Ofood[j] == self.foodlist[i]['Food ID']:
                Ofooddict = {}
                Ofooddict['Food ID'] = self.foodlist[i]['Food ID']
                Ofooddict['Food Name'] = self.foodlist[i]['Food Name']
                Ofooddict['quantity'] = Oquantity[j]
                Ofooddict['Food Price'] = self.foodlist[i]['Food Price']
                orderedfoodlist.append(Ofooddict)
                #print (orderedfoodlist)
                j+=1
                i=0
                if j >= len(Ofood):
                    break
            else:
                i+=1
        print (orderedfoodlist)
        print("Enter 1 to confirm order \nEnter 2 to reorder")
        confirm = int(input())
        if confirm == 1:
            self.update_inventory(Ofood, Oquantity)
        return confirm,orderedfoodlist
            
    def order_received(self,order):
        self.orders.append(order)
        print("order confirmed")
        return
        
    def print_orders(self):
        for i in self.orders:
            print (i)

    def income(self):
        income = 0
        for i in self.orders:
            if i.status == 'Delivered':
                if i.username.name in Users:
                    discount =0
                else:
                    discount =5
                    Users.add(i.username.name)
                    print(f'{discount}% discount is for the user {i.username.name}')
                    item = i.item
                    qty = i.qty
                    price = self.menu.get(item)
            income += (price * qty)*((100-discount)/100)
        print(income)
        
    def update_inventory(self, foodid, qty):
        j =0
        for i in range(len(self.foodlist)):
            if foodid[j] == self.foodlist[i]['Food ID']:
                self.foodlist[i]['Food Quantity'] -= qty[j]
                j+=1
                if j >=len(foodid):
                    break
        return

# %%
class User:
    
    def __init__(self):
        self.__Uname = None
        self.__password =None
        self.phonenumber = None
        self.email = None
        self.Uaddress = None
        self.userlist = []
        self.userdata = []
        self.orderHistory= []

    def inuserlist(self,phonenum):
        phoneFlag = False
        if len(self.userlist) == 0:
            return phoneFlag
       
        for i in self.userlist:
            if i == phonenum:
                phoneFlag = True 
                return phoneFlag
            else:
                #print(phoneFlag)
                return phoneFlag,phonenum
            

    def validate_email(self,email):
        x = re.compile(".*\@.*\.com$")      
        if x.match(email):
            return True
        else :
            print ("invalid Email\n Enter valid email")
            email1 = input()
            self.validate_email(email1)
            return True

    def validate_phone(self,phone):
        x = re.compile("[0-9]{10}")
        if x.match(str(phone)) :
            return True
        else :
            print ("invalid phone number \n Enter valid phone number")
            number1 = input()
            self.validate_phone(number1)
            return True

    def address(self):
        print("Enter the locality/Street address")
        locality = input()
        print ("Enter the landmark")
        landmark = input()
        print ("Enter the city")
        city = input ()
        print ("Enter the pincode")
        pincode = int(input())
        address = locality +","+ landmark + "," + city + "-" + str(pincode)
        return address

    def registration(self):
        print("Enter the phone number")
        try:
            self.phonenumber = int(input())
        except ValueError:
            print ('phone number has to be numbers')
            self.phonenumber = int(input())
        self.validate_phone(self.phonenumber)
        phone = self.inuserlist(self.phonenumber)
        #print(phone)
        if phone == False:
            print("Enter the Full Name")
            self.__Uname = input()
            print("Enter the User Email")
            self.email = input()
            self.validate_email(self.email)
            self.Uaddress = self.address()
            print ("Enter the password")
            self.__password = input()
            user_ds = {"UserName": self.__Uname, "Password": self.__password}
            user_list = {"UserName": self.__Uname, "Password": self.__password,"Phone number" : self.phonenumber, 
                         "Email":self.email, "Address": self.Uaddress} 
            self.userdata.append(user_ds)
            self.userlist.append(user_list)

    def validate_login(self,username,password):
        for i in self.userdata:
            if i["UserName"] == username and i["Password"] == password:
                print("Login successfull")
                return True
            if i["UserName"] == username or i["Password"] == password:
                print ("Username or password incorrect\n please re enter")
                self.login()
        print("login not found, please register")


    def update_profile(self):
        print("Enter the username again")
        uname = input()
#         print ("Enter the registered phone number")
#         phone = int(input())
        print ("""press 1 to update Password
                  press 2 to update email
                  press 3 to update address""")
        update = int(input())
        for i in self.userlist:
            if i["UserName"] == uname and i["Phone number"] == phone:
                if update == 1:
                    print("Enter the new password")
                    password = input()
                    i["Password"] == password
                    print("Update successful")
                elif update == 2:
                    print ("Enter the new email")
                    email = input()
                    self.validate_email(email)
                    i["Email"] = email
                    print("Update successful")
                elif update == 3:
                    print("Enter the new address")
                    address = self.address()
                    i["Address"] = address
                    print("Update successful")
                else:
                    print("invalid entry")
                    return
            self.view_userprofile(i)
            break
        return
            
    def view_userprofile(self,index):
        for i in self.userlist:
            if i == index:
                print(i)
        
    def login(self):
        print ("UserName:")
        Username = input()
        print ("Password:")
        Password = input()
        ulogin = self.validate_login(Username,Password)
        #print(ulogin)
        if ulogin == True:
            self.options()
            return 
        else:
            print ("you need to register to order food")
            print ("Enter 1 to register or 2 to exit")
            userinput = int(input())
            if userinput == 1:
                self.registration()
            else:
                return             
            
    def options(self):
        print (" press 1 to Place New Order \n press 2 for Order History \n press 3 to update profile")
        keyedInput = int(input())
        if keyedInput not in [1,2,3]:
            print("Invalid Option")
            self.options()
            return
        if keyedInput == 1:
            self.print_menu()
        elif keyedInput == 2:
            self.view_order_history()
        elif keyedInput == 3:
            self.update_profile()
        return
    
    def order(self,fooditems,res_name = admin):
        res_name.order_received(fooditems)
        self.order_history(fooditems)
        return
    
    def order_history(self,fooditems):
        self.orderHistory.append(fooditems)
        return
        
    def view_order_history(self):
        if len(self.orderHistory) == 0:
            print ("No orders placed yet")
        for i in self.orderHistory:
            print (i)
            
    def print_menu(self,res_name = admin):
        res_name.print_items()
        print("press 1 to order and 2 to exit")
        keyedInput = int(input())
        if keyedInput not in [1,2]:
            print("Invalid Option")
            self.print_menu()
            return
        if keyedInput == 1:
            print ("""Enter the items u wish to order based on the line number of foods\n 
            E.g. 1 for tandoori and 4 for Lime mojito""")
            orderedfood = []
            print("Enter q to stop entering input")
            for i in range (5):
                orderinput = input()
                if orderinput == 'q':
                    break
                else:
                    orderedfood.append(int(orderinput))
            print("Enter the quantity of food")
            orderquantity = []
            for i in range (len(orderedfood)):
                orderinput = input()
                if orderinput == 'q':
                    break
                else:
                    orderquantity.append(int(orderinput))
        order = self.porder(orderedfood,orderquantity)
        if order == 0:
            self.print_menu()
        return
        
    def porder(self,food,quantity,res_name=admin):
        #print(food,quantity)
        foodlist =[]
        confirmation,foodlist = res_name.printorder(food,quantity)
        if confirmation == 1:
            self.order(foodlist)
        else:
            return 0

# %%
admin =Admin()
print("Enter the admin username")
Uname = input()
print("Enter the admin password")
Password = input()
validation = admin.validate(Uname,Password)
if validation == "Access granted":
    admin.set_fooditem("Tandoori chicken[8 pieces]")
#     admin.set_fooditem("Chicken Shawarma [roll]")
#     admin.set_fooditem("Paneer butter masala")
#     admin.set_fooditem("Lime Mojito [120 ml]")
#     admin.set_fooditem("Blue Moon Mojito[120 ml]")
    admin.get_fooditem()
    #admin.print_items()
else :
    print (validation)
# Out:
# Enter the admin username
# Admin
# Enter the admin password
# password
# FoodName Tandoori chicken[8 pieces]
# enter the quantity of food available
# 20
# Enter the price of the food per serve
# 250
# Enter the maximum discount for the product in percentage
# 10
# [{'Food ID': 1001, 'Food Name': 'Tandoori chicken[8 pieces]', 'Food Quantity': 20, 'Food Price': 250.0, 'Discount': 10.0}]

# %%
admin.print_items()
# Out:
# Food ID       Food name      Price
# 1001 ----- Tandoori chicken[8 pieces] ----- 250.0 ----- 10.0

# %%
snegha = User()
snegha.registration()
# Out:
# Enter the phone number
# 9943180715
# Enter the Full Name
# sne
# Enter the User Email
# sne@23.com
# Enter the locality/Street address
# amb
# Enter the landmark
# metro
# Enter the city
# chn
# Enter the pincode
# 600032
# Enter the password
# sa

# %%
snegha.login()
# Out:
# UserName:
# sne
# Password:
# sa
# Login successfull
#  press 1 to Place New Order
#  press 2 for Order History
#  press 3 to update profile
# 1
# Food ID       Food name      Price
# 1001 ----- Tandoori chicken[8 pieces] ----- 300.0 ----- 2.0
# press 1 to order and 2 to exit
# 1
# Enter the items u wish to order based on the line number of foods
#
#             E.g. 1 for tandoori and 4 for Lime mojito
# Enter q to stop entering input
# 1
# 1
# q
# Enter the quantity of food
# 2
# 1
# [{'Food ID': 1001, 'Food Name': 'Tandoori chicken[8 pieces]', 'quantity': 2, 'Food Price': 300.0}, {'Food ID': 1001, 'Food Name': 'Tandoori chicken[8 pieces]', 'quantity': 1, 'Food Price': 300.0}]
# Enter 1 to confirm order
# Enter 2 to reorder
# 1
# order confirmed

# %%
snegha.login()
# Out:
# UserName:
# sne
# Password:
# sa
# Login successfull
#  press 1 to Place New Order
#  press 2 for Order History
#  press 3 to update profile
# 2
# [{'Food ID': 1001, 'Food Name': 'Tandoori chicken[8 pieces]', 'quantity': 2, 'Food Price': 300.0}, {'Food ID': 1001, 'Food Name': 'Tandoori chicken[8 pieces]', 'quantity': 1, 'Food Price': 300.0}]

# %%
admin.income()

# %%
snegha.login()
# Out:
# UserName:
# sne
# Password:
# sa
# Login successfull
#  press 1 to Place New Order
#  press 2 for Order History
#  press 3 to update profile
# 3
# Enter the username again
# sne
# Enter the registered phone number
# 8904567890
# press 1 to update Password
#                   press 2 to update email
#                   press 3 to update address
# 1
# {'UserName': 'sne', 'Password': 'sa', 'Phone number': 9943180715, 'Email': 'sne@23.com', 'Address': 'amb,metro,chn-600032'}

# %%
swe= User()
swe.login()
# Out:
# UserName:
# swe
# Password:
# sa
# login not found, please register
# you need to register to order food
# Enter 1 to register or 2 to exit
# 1
# Enter the phone number
# 8904567890
# Enter the Full Name
# swe
# Enter the User Email
# swe@19.com
# Enter the locality/Street address
# sa
# Enter the landmark
# fd
# Enter the city
# chn
# Enter the pincode
# 600089
# Enter the password
# sad

# %%
swe.login()
# Out:
# UserName:
# swe
# Password:
# sad
# Login successfull
#  press 1 to Place New Order
#  press 2 for Order History
#  press 3 to update profile
# 3
# Enter the username again
# swe
# Enter the registered phone number
# 890456789
# press 1 to update Password
#                   press 2 to update email
#                   press 3 to update address
# 1
# {'UserName': 'swe', 'Password': 'sad', 'Phone number': 8904567890, 'Email': 'swe@19.com', 'Address': 'sa,fd,chn-600089'}
